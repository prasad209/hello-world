# %% [markdown]
# <a href="https://colab.research.google.com/github/prasad209/hello-world/blob/main/M1W3_Guided_Project_EDA_on_IMDB_Dataset_PK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## You have been hired by a rookie movie producer to help him decide what type of movies to produce and which actors to cast. You have to back your recommendations based on thorough analysis of the data he shared with you which has the list of 3000 movies and the corresponding details.
#
# ## As a data scientist, you have to first explore the data and check its sanity.
#
# ## Further, you have to answer the following questions:
# 1. ### <b> Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.</b>
# 2. ### <b>This data has information about movies made in different languages. Which language has the highest average ROI (return on investment)? </b>
# 3. ### <b> Find out the unique genres of movies in this dataset.</b>
# 4. ### <b> Make a table of all the producers and directors of each movie. Find the top 3 producers who have produced movies with the highest average RoI? </b>
# 5. ### <b> Which actor has acted in the most number of movies? Deep dive into the movies, genres and profits corresponding to this actor. </b>
# 6. ### <b>Top 3 directors prefer which actors the most? </b>

# %% [markdown]
# # Data Exploration

# %%
#Import package
import pandas as pd
import numpy as np

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
imdb_df=pd.read_csv('/content/gdrive/MyDrive/imdb_data.csv')

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
list(imdb_df.columns)
# Out:
# ['id',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'homepage',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'Keywords',
#  'cast',
#  'crew',
#  'revenue']

# %%
#Highest revenue
imdb_df['revenue'].max()
# Out:
# 1519557910

# %%
#row number of highest revenue
imdb_df['revenue'].idxmax()
# Out:
# 1126

# %%
imdb_df.loc[df['revenue'].idxmax()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-26f6c7274537> in <module>()
# ----> 1 imdb_df.loc[df['revenue'].idxmax()]
#
# NameError: name 'df' is not defined

# %%
imdb_df[['revenue','original_language']]
# Out:
#         revenue original_language
# 0      12314651                en
# 1      95149435                en
# 2      13092000                en
# 3      16000000                hi
# 4       3923970                ko
# ...         ...               ...
# 2995    1596687                en
# 2996     180590                sv
# 2997   89456761                en
# 2998  171963386                en
# 2999   82087155                en
#
# [3000 rows x 2 columns]

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
imdb_df['crew'][0]
# Out:
# '[{\'credit_id\': \'59ac067c92514107af02c8c8\', \'department\': \'Directing\', \'gender\': 0, \'id\': 1449071, \'job\': \'First Assistant Director\', \'name\': \'Kelly Cantley\', \'profile_path\': None}, {\'credit_id\': \'52fe4ee7c3a36847f82afad7\', \'department\': \'Directing\', \'gender\': 2, \'id\': 3227, \'job\': \'Director\', \'name\': \'Steve Pink\', \'profile_path\': \'/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg\'}, {\'credit_id\': \'5524ed25c3a3687ded000d88\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Writer\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed2d925141720c001128\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Characters\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed3d92514166c1004a5d\', \'department\': \'Production\', \'gender\': 2, \'id\': 57822, \'job\': \'Producer\', \'name\': \'Andrew Panay\',
# ...

# %%
type(imdb_df['crew'][0])
# Out:
# str

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
imdb_df.loc[0,'crew']
# Out:
# '[{\'credit_id\': \'59ac067c92514107af02c8c8\', \'department\': \'Directing\', \'gender\': 0, \'id\': 1449071, \'job\': \'First Assistant Director\', \'name\': \'Kelly Cantley\', \'profile_path\': None}, {\'credit_id\': \'52fe4ee7c3a36847f82afad7\', \'department\': \'Directing\', \'gender\': 2, \'id\': 3227, \'job\': \'Director\', \'name\': \'Steve Pink\', \'profile_path\': \'/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg\'}, {\'credit_id\': \'5524ed25c3a3687ded000d88\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Writer\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed2d925141720c001128\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Characters\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed3d92514166c1004a5d\', \'department\': \'Production\', \'gender\': 2, \'id\': 57822, \'job\': \'Producer\', \'name\': \'Andrew Panay\',
# ...

# %%
type(imdb_df.loc[0,'crew'])
# Out:
# str

# %%
crew_list=eval(imdb_df.loc[0,'crew'])

# %%
crew_list
# Out:
# [{'credit_id': '59ac067c92514107af02c8c8',
#   'department': 'Directing',
#   'gender': 0,
#   'id': 1449071,
#   'job': 'First Assistant Director',
#   'name': 'Kelly Cantley',
#   'profile_path': None},
#  {'credit_id': '52fe4ee7c3a36847f82afad7',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 3227,
#   'job': 'Director',
#   'name': 'Steve Pink',
#   'profile_path': '/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg'},
#  {'credit_id': '5524ed25c3a3687ded000d88',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Writer',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed2d925141720c001128',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 347335,
#   'job': 'Characters',
#   'name': 'Josh Heald',
#   'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'},
#  {'credit_id': '5524ed3d92514166c1004a5d',
#   'department': 'Production',
#   'gender': 2,
#   'id': 57822,
#   'job': 'Producer',
# ...

# %%
type(crew_list)
# Out:
# list

# %%
len(crew_list)
# Out:
# 72

# %%
imdb_df.loc[0,'genres']
# Out:
# "[{'id': 35, 'name': 'Comedy'}]"

# %%
eval(imdb_df.loc[0,'genres'])
# Out:
# [{'id': 35, 'name': 'Comedy'}]

# %%
imdb_df['genres']
# Out:
# 0                          [{'id': 35, 'name': 'Comedy'}]
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                           [{'id': 18, 'name': 'Drama'}]
# 3       [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#                               ...
# 2995    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997    [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# Name: genres, Length: 3000, dtype: object

# %%
def str_converter(str):
  return eval(str)

# %%
#here's the way u can apply lambda to all rows...
#interpretation:apply function on df genres for all rows such that eval function is applied for every row of genres
# here we are getting error bcoz some values in the series are not a string
imdb_df['genres']=imdb_df['genres'].apply(lambda row: eval(row['genres']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-2a04438f6edd> in <module>()
#       2 #interpretation:apply function on df genres for all rows such that eval function is applied for every row of genres
#       3 # here we are getting error bcoz some values in the series are not a string
# ----> 4 imdb_df['genres']=imdb_df['genres'].apply(lambda row: eval(row['genres']))
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
# ...

# %%
# way 2 for using  apply function
## here we are getting error bcoz some values in the series are not a string
imdb_df['genres']=imdb_df['genres'].apply(str_converter)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-6680d510e269> in <module>()
#       1 # way 2 for using  apply function
#       2 ## here we are getting error bcoz some values in the series are not a string
# ----> 3 imdb_df['genres']=imdb_df['genres'].apply(str_converter)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ...

# %%
#lets see which columns got null values
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
imdb_df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
columns_to_keep=['budget', 'genres', 
       'imdb_id', 'original_language','original_title','cast', 'crew', 'revenue']

# %%
#since this is a list, we need df
imdb_df=imdb_df[columns_to_keep]

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             3000 non-null   int64
#  1   genres             2993 non-null   object
#  2   imdb_id            3000 non-null   object
#  3   original_language  3000 non-null   object
#  4   original_title     3000 non-null   object
#  5   cast               2987 non-null   object
#  6   crew               2984 non-null   object
#  7   revenue            3000 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 187.6+ KB

# %%
#this will drop null values....remember it drops the complete row   
imdb_non_null_df=imdb_df.dropna()

# %%
imdb_non_null_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2978 entries, 0 to 2999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             2978 non-null   int64
#  1   genres             2978 non-null   object
#  2   imdb_id            2978 non-null   object
#  3   original_language  2978 non-null   object
#  4   original_title     2978 non-null   object
#  5   cast               2978 non-null   object
#  6   crew               2978 non-null   object
#  7   revenue            2978 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 209.4+ KB

# %%
imdb_non_null_df_genres=imdb_non_null_df["genres"].apply(str_converter)
imdb_non_null_df_genres.head()
# Out:
# 0                       [{'id': 35, 'name': 'Comedy'}]
# 1    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                        [{'id': 18, 'name': 'Drama'}]
# 3    [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# Name: genres, dtype: object

# %%
for i in ["genres","cast","crew"]:
  imdb_non_null_df[i].apply(str_converter)

# %%
imdb_non_null_df.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
#here we converted str columns to list for imdb_non_null_df which is another df , but our main df is imdb_df and we want that operation on this one so 
imdb_df.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
imdb_df.isna().head()
#this is boolean Question...false means isna is false so value is there
# Out:
#    budget  genres  imdb_id  original_language  original_title   cast   crew  \
# 0   False   False    False              False           False  False  False
# 1   False   False    False              False           False  False  False
# 2   False   False    False              False           False  False  False
# 3   False   False    False              False           False  False  False
# 4   False   False    False              False           False  False  False
#
#    revenue
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %%
#if we apply isna to specific column then it shows Nan entries i.e entries where its value is True
imdb_df[imdb_df['genres'].isna()]
# Out:
#        budget genres    imdb_id original_language  \
# 470   2000000    NaN  tt0349159                en
# 1622   400000    NaN  tt0261755                en
# 1814  2700000    NaN  tt0110289                it
# 1819        0    NaN  tt0352622                ru
# 2423   500000    NaN  tt0984177                en
# 2686        0    NaN  tt0833448                ru
# 2900   200000    NaN  tt1766044                en
#
#                                        original_title  \
# 470   The Book of Mormon Movie, Volume 1: The Journey
# 1622                                          Jackpot
# 1814                                     Курочка Ряба
# 1819                          Небо. Самолёт. Девушка.
# 2423                                        Amarkalam
# 2686                                             Лифт
# 2900                          Poslednyaya skazka Rity
#
#                                                    cast  \
# 470   [{'cast_id': 1, 'character': 'Sam', 'credit_id...
# ...

# %%
imdb_df.loc[imdb_df['genres'].isna(),'genres']
# Out:
# 470     NaN
# 1622    NaN
# 1814    NaN
# 1819    NaN
# 2423    NaN
# 2686    NaN
# 2900    NaN
# Name: genres, dtype: object

# %%
imdb_df.loc[~imdb_df['genres'].isna(),'genres']
# Out:
# 0                          [{'id': 35, 'name': 'Comedy'}]
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                           [{'id': 18, 'name': 'Drama'}]
# 3       [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#                               ...
# 2995    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997    [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# Name: genres, Length: 2993, dtype: object

# %%
#  ~ of isna() is equivalent to notna(), so u can directly use notna() function
imdb_df.loc[imdb_df['genres'].notna(),'genres']
# Out:
# 0                          [{'id': 35, 'name': 'Comedy'}]
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                           [{'id': 18, 'name': 'Drama'}]
# 3       [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#                               ...
# 2995    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997    [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# Name: genres, Length: 2993, dtype: object

# %%
# we need to convert str to list for non missing values
#this is failing bcoz we already did this in the earlier line
imdb_df.loc[~imdb_df['genres'].isna(),'genres'].apply(str_converter)
# Out:
# 0                          [{'id': 35, 'name': 'Comedy'}]
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                           [{'id': 18, 'name': 'Drama'}]
# 3       [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#                               ...
# 2995    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997    [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# Name: genres, Length: 2993, dtype: object

# %%
#why we did below step? bcoz we only want to replace the strings with lists for values which are there,and not for missing values.
#if we equate dataframe name to imdb_df.loc[~imdb_df['genres'].isna(),'genres'].apply(str_converter) then it will update original df 
#imdb_df.loc[~imdb_df['cast'].isna(),'cast']=imdb_df.loc[~imdb_df['cast'].isna(),'cast'].apply(str_converter)
#imdb_df.loc[~imdb_df['crew'].isna(),'crew']=imdb_df.loc[~imdb_df['crew'].isna(),'crew'].apply(str_converter)
imdb_df.loc[imdb_df['genres'].notna(),'genres']
# Out:
# 0                          [{'id': 35, 'name': 'Comedy'}]
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                           [{'id': 18, 'name': 'Drama'}]
# 3       [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#                               ...
# 2995    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997    [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# Name: genres, Length: 2993, dtype: object

# %%
imdb_df.loc[imdb_df['crew'].notna(),'crew']
# Out:
# 0       [{'credit_id': '59ac067c92514107af02c8c8', 'de...
# 1       [{'credit_id': '52fe43fe9251416c7502563d', 'de...
# 2       [{'credit_id': '54d5356ec3a3683ba0000039', 'de...
# 3       [{'credit_id': '52fe48779251416c9108d6eb', 'de...
# 4       [{'credit_id': '52fe464b9251416c75073b43', 'de...
#                               ...
# 2995    [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...
# 2996    [{'credit_id': '5716b72ac3a3686678012c84', 'de...
# 2997    [{'credit_id': '52fe443a9251416c7502d579', 'de...
# 2998    [{'credit_id': '556f817b9251410866000a63', 'de...
# 2999    [{'credit_id': '5391990d0e0a260fb5001629', 'de...
# Name: crew, Length: 2984, dtype: object

# %%
imdb_df.loc[imdb_df['cast'].notna(),'cast']
# Out:
# 0       [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1       [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2       [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3       [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4       [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#                               ...
# 2995    [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996    [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997    [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998    [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999    [{'cast_id': 2, 'character': 'Nathan Harper', ...
# Name: cast, Length: 2987, dtype: object

# %%
imdb_df.loc[~imdb_df['genres'].isna(),'genres']
# Out:
# 0                          [{'id': 35, 'name': 'Comedy'}]
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                           [{'id': 18, 'name': 'Drama'}]
# 3       [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#                               ...
# 2995    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997    [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# Name: genres, Length: 2993, dtype: object

# %%
imdb_df_new=imdb_df.copy()

# %%
imdb_df_new.head(3)
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# ...

# %%
imdb_df_new.loc[imdb_df_new['genres'].isna()]
# Out:
#        budget genres    imdb_id original_language  \
# 470   2000000    NaN  tt0349159                en
# 1622   400000    NaN  tt0261755                en
# 1814  2700000    NaN  tt0110289                it
# 1819        0    NaN  tt0352622                ru
# 2423   500000    NaN  tt0984177                en
# 2686        0    NaN  tt0833448                ru
# 2900   200000    NaN  tt1766044                en
#
#                                        original_title  \
# 470   The Book of Mormon Movie, Volume 1: The Journey
# 1622                                          Jackpot
# 1814                                     Курочка Ряба
# 1819                          Небо. Самолёт. Девушка.
# 2423                                        Amarkalam
# 2686                                             Лифт
# 2900                          Poslednyaya skazka Rity
#
#                                                    cast  \
# 470   [{'cast_id': 1, 'character': 'Sam', 'credit_id...
# ...

# %% [markdown]
# Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.

# %%
imdb_df.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
imdb_df['revenue'].max()
# Out:
# 1519557910

# %%
imdb_df['revenue'].idxmax()
# Out:
# 1126

# %%
imdb_df.loc[1126,'revenue']
# Out:
# 1519557910

# %%
imdb_df.loc[1126]
# Out:
# budget                                                       220000000
# genres               [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# imdb_id                                                      tt0848228
# original_language                                                   en
# original_title                                            The Avengers
# cast                 [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# crew                 [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...
# revenue                                                     1519557910
# Name: 1126, dtype: object

# %%
imdb_df.loc[1126,['genres','original_title']]
# Out:
# genres            [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# original_title                                         The Avengers
# Name: 1126, dtype: object

# %%
#my answer---Which movie made the highest profit?.......BUT REVENUE IS NOT PROFIT, REVENUE-BUDGET IS
#This is answer for question "Movie with max revenue"
imdb_df.loc[imdb_df['revenue'].idxmax(),'original_title']
# Out:
# 'The Avengers'

# %%
imdb_df['Profit']=imdb_df['budget']-imdb_df['revenue']
imdb_df['Profit']
# Out:
# 0         1685349
# 1       -55149435
# 2        -9792000
# 3       -14800000
# 4        -3923970
#           ...
# 2995     -1596687
# 2996      -180590
# 2997    -24456761
# 2998   -129963386
# 2999    -47087155
# Name: Profit, Length: 3000, dtype: int64

# %%
#Actual answer
imdb_df.loc[imdb_df['Profit'].idxmax(),'original_title']
# Out:
# 'Valerian and the City of a Thousand Planets'

# %% [markdown]
# Who were its producer and director? Identify the actors in that film.

# %%
imdb_df['crew'].head(1)[0]
# Out:
# '[{\'credit_id\': \'59ac067c92514107af02c8c8\', \'department\': \'Directing\', \'gender\': 0, \'id\': 1449071, \'job\': \'First Assistant Director\', \'name\': \'Kelly Cantley\', \'profile_path\': None}, {\'credit_id\': \'52fe4ee7c3a36847f82afad7\', \'department\': \'Directing\', \'gender\': 2, \'id\': 3227, \'job\': \'Director\', \'name\': \'Steve Pink\', \'profile_path\': \'/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg\'}, {\'credit_id\': \'5524ed25c3a3687ded000d88\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Writer\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed2d925141720c001128\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Characters\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed3d92514166c1004a5d\', \'department\': \'Production\', \'gender\': 2, \'id\': 57822, \'job\': \'Producer\', \'name\': \'Andrew Panay\',
# ...

# %%
imdb_df['cast'].head()[0]
# Out:
# "[{'cast_id': 4, 'character': 'Lou', 'credit_id': '52fe4ee7c3a36847f82afae7', 'gender': 2, 'id': 52997, 'name': 'Rob Corddry', 'order': 0, 'profile_path': '/k2zJL0V1nEZuFT08xUdOd3ucfXz.jpg'}, {'cast_id': 5, 'character': 'Nick', 'credit_id': '52fe4ee7c3a36847f82afaeb', 'gender': 2, 'id': 64342, 'name': 'Craig Robinson', 'order': 1, 'profile_path': '/tVaRMkJXOEVhYxtnnFuhqW0Rjzz.jpg'}, {'cast_id': 6, 'character': 'Jacob', 'credit_id': '52fe4ee7c3a36847f82afaef', 'gender': 2, 'id': 54729, 'name': 'Clark Duke', 'order': 2, 'profile_path': '/oNzK0umwm5Wn0wyEbOy6TVJCSBn.jpg'}, {'cast_id': 7, 'character': 'Adam Jr.', 'credit_id': '52fe4ee7c3a36847f82afaf3', 'gender': 2, 'id': 36801, 'name': 'Adam Scott', 'order': 3, 'profile_path': '/5gb65xz8bzd42yjMAl4zwo4cvKw.jpg'}, {'cast_id': 8, 'character': 'Hot Tub Repairman', 'credit_id': '52fe4ee7c3a36847f82afaf7', 'gender': 2, 'id': 54812, 'name': 'Chevy Chase', 'order': 4, 'profile_path': '/svjpyYtPwtjvRxX9IZnOmOkhDOt.jpg'}, {'cast_id': 9, 'charact
# ...

# %%
imdb_df_new['budget'].min()=imdb_df_new['budget'].median()
# Out:
#   File "<ipython-input-62-97fcec2b9cf2>", line 1
#     imdb_df_new['budget'].min()=imdb_df_new['budget'].median()
#                                                               ^
# SyntaxError: can't assign to function call

# %%
imdb_df_new.loc[imdb_df_new['budget'].min(),'budget]'=imdb_df_new['budget'].median()
# Out:
#   File "<ipython-input-63-b4fc7e5f9e29>", line 1
#     imdb_df_new.loc[imdb_df_new['budget'].min(),'budget]'=imdb_df_new['budget'].median()
#                                                          ^
# SyntaxError: invalid syntax

# %%
[imdb_df_new.loc[imdb_df_new['budget']<1000]=imdb_df_new['budget'].median()
# Out:
#   File "<ipython-input-64-928e884bc7c8>", line 1
#     [imdb_df_new.loc[imdb_df_new['budget']<1000]=imdb_df_new['budget'].median()
#                                                 ^
# SyntaxError: invalid syntax

# %%
imdb_df_new['budget'].median()
# Out:
# 8000000.0

# %%
#the problem here is that minimum value of budget is 0 which is hard to digest and also  first 25% are 0 so we need to run some heuristics like 
#replace values <1000 to median
imdb_df_new[imdb_df_new['budget']<1000]=imdb_df_new[imdb_df_new['budget']>=1000].median()
#this is failing, we must use loc
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-d0ed980c6ecf> in <module>()
#       1 #the problem here is that minimum value of budget is 0 which is hard to digest and also  first 25% are 0 so we need to run some heuristics like
#       2 #replace values <1000 to median
# ----> 3 imdb_df_new[imdb_df_new['budget']<1000]=imdb_df_new[imdb_df_new['budget']>=1000].median()
#       4 #this is failing, we must use loc
#
# ...

# %%
imdb_df_new.describe()
# Out:
#              budget       revenue
# count  3.000000e+03  3.000000e+03
# mean   2.253133e+07  6.672585e+07
# std    3.702609e+07  1.375323e+08
# min    0.000000e+00  1.000000e+00
# 25%    0.000000e+00  2.379808e+06
# 50%    8.000000e+06  1.680707e+07
# 75%    2.900000e+07  6.891920e+07
# max    3.800000e+08  1.519558e+09

# %%
imdb_df_new.loc[imdb_df_new['budget']<1000,'budget']=imdb_df_new.loc[imdb_df_new['budget']>=1000,'budget'].median()
# we will do same for revenue
imdb_df_new.loc[imdb_df_new['revenue']<1000,'revenue']=imdb_df_new.loc[imdb_df_new['revenue']>=1000,'revenue'].median()

# %%
imdb_df_new.describe()
# Out:
#              budget       revenue
# count  3.000000e+03  3.000000e+03
# mean   2.708250e+07  6.705811e+07
# std    3.492773e+07  1.373917e+08
# min    2.500000e+03  1.404000e+03
# 25%    1.000000e+07  2.947600e+06
# 50%    1.645000e+07  1.748753e+07
# 75%    2.900000e+07  6.891920e+07
# max    3.800000e+08  1.519558e+09

# %%
imdb_df_new['Profit']=imdb_df_new['revenue']-imdb_df_new['budget']

# %%
imdb_df_new.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4  16450000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
#now we can answer -- the highest profit
#finally , i got it
imdb_df_new.loc[imdb_df_new['Profit'].idxmax(),'Profit']
# Out:
# 1316249360

# %% [markdown]
# Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.

# %%
#movie which made the highest profit
imdb_df_new.loc[imdb_df_new['Profit'].idxmax(),'original_title']
# Out:
# 'Furious 7'

# %%
#alma way
max_profit_movie_df=imdb_df_new[imdb_df_new['Profit']==imdb_df_new['Profit'].max()]

# %%
max_profit_movie_df
# Out:
#          budget                          genres    imdb_id original_language  \
# 1761  190000000  [{'id': 28, 'name': 'Action'}]  tt2820852                en
#
#      original_title                                               cast  \
# 1761      Furious 7  [{'cast_id': 17, 'character': 'Dominic Toretto...
#
#                                                    crew     revenue  \
# 1761  [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360
#
#           Profit
# 1761  1316249360

# %%
max_profit_movie_df['crew']
# Out:
# 1761    [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...
# Name: crew, dtype: object

# %%
max_profit_movie_df['crew'].values
# Out:
# array(['[{\'credit_id\': \'52fe4cc8c3a36847f823e681\', \'department\': \'Production\', \'gender\': 2, \'id\': 12835, \'job\': \'Producer\', \'name\': \'Vin Diesel\', \'profile_path\': \'/7rwSXluNWZAluYMOEWBxkPmckES.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e687\', \'department\': \'Production\', \'gender\': 2, \'id\': 11874, \'job\': \'Producer\', \'name\': \'Neal H. Moritz\', \'profile_path\': \'/cNcsEYmoS4niCz3UkVAA09dUIob.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e68d\', \'department\': \'Writing\', \'gender\': 2, \'id\': 58191, \'job\': \'Writer\', \'name\': \'Chris Morgan\', \'profile_path\': \'/dUGxIwFBLrSFLImxjeda1krndMO.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e693\', \'department\': \'Writing\', \'gender\': 0, \'id\': 8162, \'job\': \'Characters\', \'name\': \'Gary Scott Thompson\', \'profile_path\': \'/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e699\', \'department\': \'Directing\', \'gender\': 2, \'id\': 2127, \'job\': \'Director
# ...

# %%
max_profit_movie_df.iloc[0]['crew']
# Out:
# '[{\'credit_id\': \'52fe4cc8c3a36847f823e681\', \'department\': \'Production\', \'gender\': 2, \'id\': 12835, \'job\': \'Producer\', \'name\': \'Vin Diesel\', \'profile_path\': \'/7rwSXluNWZAluYMOEWBxkPmckES.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e687\', \'department\': \'Production\', \'gender\': 2, \'id\': 11874, \'job\': \'Producer\', \'name\': \'Neal H. Moritz\', \'profile_path\': \'/cNcsEYmoS4niCz3UkVAA09dUIob.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e68d\', \'department\': \'Writing\', \'gender\': 2, \'id\': 58191, \'job\': \'Writer\', \'name\': \'Chris Morgan\', \'profile_path\': \'/dUGxIwFBLrSFLImxjeda1krndMO.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e693\', \'department\': \'Writing\', \'gender\': 0, \'id\': 8162, \'job\': \'Characters\', \'name\': \'Gary Scott Thompson\', \'profile_path\': \'/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e699\', \'department\': \'Directing\', \'gender\': 2, \'id\': 2127, \'job\': \'Director\', \'n
# ...

# %%
crew_list=eval(max_profit_movie_df.iloc[0]['crew'])
crew_list
#print(type(crew_list))
# Out:
# [{'credit_id': '52fe4cc8c3a36847f823e681',
#   'department': 'Production',
#   'gender': 2,
#   'id': 12835,
#   'job': 'Producer',
#   'name': 'Vin Diesel',
#   'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e687',
#   'department': 'Production',
#   'gender': 2,
#   'id': 11874,
#   'job': 'Producer',
#   'name': 'Neal H. Moritz',
#   'profile_path': '/cNcsEYmoS4niCz3UkVAA09dUIob.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e68d',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 58191,
#   'job': 'Writer',
#   'name': 'Chris Morgan',
#   'profile_path': '/dUGxIwFBLrSFLImxjeda1krndMO.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e693',
#   'department': 'Writing',
#   'gender': 0,
#   'id': 8162,
#   'job': 'Characters',
#   'name': 'Gary Scott Thompson',
#   'profile_path': '/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e699',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 2127,
# ...

# %%
for elem in crew_list:
  if elem['job']=='Director':
    print(f"The name of director is {elem['name']}")
  if elem['job']=='Producer':
    print(f"The name of Producer is {elem['name']}")
# Out:
# The name of Producer is Vin Diesel
# The name of Producer is Neal H. Moritz
# The name of director is James Wan
# The name of Producer is Michael Fottrell
# The name of Producer is Brandon Birtell

# %%
#another effective way we can do this...
Producer_list=[]
Director_list=[]
for elem in crew_list:
  if elem['job']=='Director':
    Director_list.append(elem['name'])
  if elem['job']=='Producer':
    Producer_list.append(elem['name'])

# %%
Producer_list,Director_list
# Out:
# (['Vin Diesel', 'Neal H. Moritz', 'Michael Fottrell', 'Brandon Birtell'],
#  ['James Wan'])

# %%
#passing a list to see name of movie and profit it made
imdb_df_new.loc[imdb_df_new['Profit'].idxmax(),['original_title','Profit']]
# Out:
# original_title     Furious 7
# Profit            1316249360
# Name: 1761, dtype: object

# %%
imdb_df_new.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4  16450000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
#let's see where we can get the director's name  for each movie
imdb_df_new.loc[0,['genres','cast']]
#genres column isnt usefule for this question 1, but lets see what cast column contains
# Out:
# genres                       [{'id': 35, 'name': 'Comedy'}]
# cast      [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# Name: 0, dtype: object

# %%
imdb_df_new.loc[0,['cast'][0]]
# Out:
# "[{'cast_id': 4, 'character': 'Lou', 'credit_id': '52fe4ee7c3a36847f82afae7', 'gender': 2, 'id': 52997, 'name': 'Rob Corddry', 'order': 0, 'profile_path': '/k2zJL0V1nEZuFT08xUdOd3ucfXz.jpg'}, {'cast_id': 5, 'character': 'Nick', 'credit_id': '52fe4ee7c3a36847f82afaeb', 'gender': 2, 'id': 64342, 'name': 'Craig Robinson', 'order': 1, 'profile_path': '/tVaRMkJXOEVhYxtnnFuhqW0Rjzz.jpg'}, {'cast_id': 6, 'character': 'Jacob', 'credit_id': '52fe4ee7c3a36847f82afaef', 'gender': 2, 'id': 54729, 'name': 'Clark Duke', 'order': 2, 'profile_path': '/oNzK0umwm5Wn0wyEbOy6TVJCSBn.jpg'}, {'cast_id': 7, 'character': 'Adam Jr.', 'credit_id': '52fe4ee7c3a36847f82afaf3', 'gender': 2, 'id': 36801, 'name': 'Adam Scott', 'order': 3, 'profile_path': '/5gb65xz8bzd42yjMAl4zwo4cvKw.jpg'}, {'cast_id': 8, 'character': 'Hot Tub Repairman', 'credit_id': '52fe4ee7c3a36847f82afaf7', 'gender': 2, 'id': 54812, 'name': 'Chevy Chase', 'order': 4, 'profile_path': '/svjpyYtPwtjvRxX9IZnOmOkhDOt.jpg'}, {'cast_id': 9, 'charact
# ...

# %%
imdb_df_new.loc[0,'cast']
# Out:
# "[{'cast_id': 4, 'character': 'Lou', 'credit_id': '52fe4ee7c3a36847f82afae7', 'gender': 2, 'id': 52997, 'name': 'Rob Corddry', 'order': 0, 'profile_path': '/k2zJL0V1nEZuFT08xUdOd3ucfXz.jpg'}, {'cast_id': 5, 'character': 'Nick', 'credit_id': '52fe4ee7c3a36847f82afaeb', 'gender': 2, 'id': 64342, 'name': 'Craig Robinson', 'order': 1, 'profile_path': '/tVaRMkJXOEVhYxtnnFuhqW0Rjzz.jpg'}, {'cast_id': 6, 'character': 'Jacob', 'credit_id': '52fe4ee7c3a36847f82afaef', 'gender': 2, 'id': 54729, 'name': 'Clark Duke', 'order': 2, 'profile_path': '/oNzK0umwm5Wn0wyEbOy6TVJCSBn.jpg'}, {'cast_id': 7, 'character': 'Adam Jr.', 'credit_id': '52fe4ee7c3a36847f82afaf3', 'gender': 2, 'id': 36801, 'name': 'Adam Scott', 'order': 3, 'profile_path': '/5gb65xz8bzd42yjMAl4zwo4cvKw.jpg'}, {'cast_id': 8, 'character': 'Hot Tub Repairman', 'credit_id': '52fe4ee7c3a36847f82afaf7', 'gender': 2, 'id': 54812, 'name': 'Chevy Chase', 'order': 4, 'profile_path': '/svjpyYtPwtjvRxX9IZnOmOkhDOt.jpg'}, {'cast_id': 9, 'charact
# ...

# %%
imdb_df_new.loc[0,'crew']
# Out:
# '[{\'credit_id\': \'59ac067c92514107af02c8c8\', \'department\': \'Directing\', \'gender\': 0, \'id\': 1449071, \'job\': \'First Assistant Director\', \'name\': \'Kelly Cantley\', \'profile_path\': None}, {\'credit_id\': \'52fe4ee7c3a36847f82afad7\', \'department\': \'Directing\', \'gender\': 2, \'id\': 3227, \'job\': \'Director\', \'name\': \'Steve Pink\', \'profile_path\': \'/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg\'}, {\'credit_id\': \'5524ed25c3a3687ded000d88\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Writer\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed2d925141720c001128\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Characters\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed3d92514166c1004a5d\', \'department\': \'Production\', \'gender\': 2, \'id\': 57822, \'job\': \'Producer\', \'name\': \'Andrew Panay\',
# ...

# %%
imdb_df_new.info()
#this shows there are some na /missing values in this df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             3000 non-null   int64
#  1   genres             2993 non-null   object
#  2   imdb_id            3000 non-null   object
#  3   original_language  3000 non-null   object
#  4   original_title     3000 non-null   object
#  5   cast               2987 non-null   object
#  6   crew               2984 non-null   object
#  7   revenue            3000 non-null   int64
#  8   Profit             3000 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 211.1+ KB

# %% [markdown]
# Identify the actors for highest profitable film....

# %%
imdb_df_new['cast'][0]
# Out:
# "[{'cast_id': 4, 'character': 'Lou', 'credit_id': '52fe4ee7c3a36847f82afae7', 'gender': 2, 'id': 52997, 'name': 'Rob Corddry', 'order': 0, 'profile_path': '/k2zJL0V1nEZuFT08xUdOd3ucfXz.jpg'}, {'cast_id': 5, 'character': 'Nick', 'credit_id': '52fe4ee7c3a36847f82afaeb', 'gender': 2, 'id': 64342, 'name': 'Craig Robinson', 'order': 1, 'profile_path': '/tVaRMkJXOEVhYxtnnFuhqW0Rjzz.jpg'}, {'cast_id': 6, 'character': 'Jacob', 'credit_id': '52fe4ee7c3a36847f82afaef', 'gender': 2, 'id': 54729, 'name': 'Clark Duke', 'order': 2, 'profile_path': '/oNzK0umwm5Wn0wyEbOy6TVJCSBn.jpg'}, {'cast_id': 7, 'character': 'Adam Jr.', 'credit_id': '52fe4ee7c3a36847f82afaf3', 'gender': 2, 'id': 36801, 'name': 'Adam Scott', 'order': 3, 'profile_path': '/5gb65xz8bzd42yjMAl4zwo4cvKw.jpg'}, {'cast_id': 8, 'character': 'Hot Tub Repairman', 'credit_id': '52fe4ee7c3a36847f82afaf7', 'gender': 2, 'id': 54812, 'name': 'Chevy Chase', 'order': 4, 'profile_path': '/svjpyYtPwtjvRxX9IZnOmOkhDOt.jpg'}, {'cast_id': 9, 'charact
# ...

# %%
max_profit_movie_df['cast']
# Out:
# 1761    [{'cast_id': 17, 'character': 'Dominic Toretto...
# Name: cast, dtype: object

# %%
cast_list=eval(max_profit_movie_df.iloc[0]['cast'])
cast_list
# Out:
# [{'cast_id': 17,
#   'character': 'Dominic Toretto',
#   'credit_id': '5431dfd10e0a265915002c34',
#   'gender': 2,
#   'id': 12835,
#   'name': 'Vin Diesel',
#   'order': 0,
#   'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'},
#  {'cast_id': 19,
#   'character': "Brian O'Conner",
#   'credit_id': '5431dfe4c3a3681143002b98',
#   'gender': 2,
#   'id': 8167,
#   'name': 'Paul Walker',
#   'order': 1,
#   'profile_path': '/iqvYezRoEY5k8wnlfHriHQfl5dX.jpg'},
#  {'cast_id': 18,
#   'character': 'Hobbs',
#   'credit_id': '5431dfdbc3a36831a6004376',
#   'gender': 2,
#   'id': 18918,
#   'name': 'Dwayne Johnson',
#   'order': 2,
#   'profile_path': '/kuqFzlYMc2IrsOyPznMd1FroeGq.jpg'},
#  {'cast_id': 20,
#   'character': 'Letty',
#   'credit_id': '5431dfeec3a36811ef002c75',
#   'gender': 1,
#   'id': 17647,
#   'name': 'Michelle Rodriguez',
#   'order': 3,
#   'profile_path': '/v37VK0MNuRuJOCKPKJcZAJXRA5r.jpg'},
#  {'cast_id': 28,
#   'character': 'Roman',
# ...

# %%
actors_list=[]
for act in cast_list:
  actors_list.append(act['name'])

# %%
actors_list
# Out:
# ['Vin Diesel',
#  'Paul Walker',
#  'Dwayne Johnson',
#  'Michelle Rodriguez',
#  'Tyrese Gibson',
#  'Ludacris',
#  'Jordana Brewster',
#  'Djimon Hounsou',
#  'Tony Jaa',
#  'Ronda Rousey',
#  'Nathalie Emmanuel',
#  'Kurt Russell',
#  'Jason Statham',
#  'Sung Kang',
#  'Gal Gadot',
#  'Lucas Black',
#  'Elsa Pataky',
#  'Noel Gugliemi',
#  'John Brotherton',
#  'Luke Evans',
#  'Ali Fazal',
#  'Miller Kimsey',
#  'Charlie Kimsey',
#  'Eden Estrella',
#  'Gentry White',
#  'Iggy Azalea',
#  'Jon Lee Brody',
#  'Levy Tran',
#  'Anna Colwell',
#  'Viktor Hernandez',
#  'Steve Coulter',
#  'Robert Pralgo',
#  'Antwan Mills',
#  'J.J. Phillips',
#  'Jorge Ferragut',
#  'Sara Sohn',
#  'Benjamin Blankenship',
#  'D.J. Hapa',
#  'T-Pain',
#  'Brian Mahoney',
#  'Brittney Alger',
#  'Romeo Santos',
#  'Jocelin Donahue',
#  'Stephanie Langston',
#  'Jorge-Luis Pallo',
#  'Tego Calder√≥n',
#  'Nathalie Kelley',
#  'Shad Moss',
#  'Don Omar',
#  'Klement Tinaj',
#  'Caleb Walker',
# ...

# %% [markdown]
# This data has information about movies made in different languages. Which language has the highest average ROI (return on investment)?

# %%
#ROI=Profit/Budget

# %%
imdb_df_new['ROI']=100* imdb_df_new['Profit']/imdb_df_new['budget']

# %%
imdb_df_new.head()

# %%
test1_df=imdb_non_null_df.dropna()
test1_df.head()
#learing:dropna() does not drop 0 coz its a number
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
roi_lang_df=imdb_df_new.groupby('original_language')['ROI'].mean().reset_index()

# %%
roi_lang_df
# Out:
#    original_language           ROI
# 0                 ar    -91.807009
# 1                 bn    -96.739429
# 2                 cn     86.002479
# 3                 cs    -99.894267
# 4                 da     24.702661
# 5                 de    510.347257
# 6                 el   5198.013245
# 7                 en    929.987781
# 8                 es    103.433478
# 9                 fa      3.235168
# 10                fi    -30.319235
# 11                fr     51.900020
# 12                he    456.292450
# 13                hi    249.618424
# 14                hu    -95.535384
# 15                id    -41.617578
# 16                it     22.136747
# 17                ja    122.763087
# 18                ko  11277.949295
# 19                ml    370.833333
# 20                mr    193.333333
# 21                nb     18.847943
# 22                nl    -24.142008
# 23                no     24.155275
# 24                pl    395.816987
# 25                pt    -29.291459
# ...

# %%
#way1-My way
roi_lang_df.loc[roi_lang_df['ROI'].idxmax(),['original_language','ROI']]
# Out:
# original_language              ko
# ROI                  11277.949295
# Name: 18, dtype: object

# %%
#way 2-Alma way
#this gives the row/observation where ROI is max
roi_lang_df[roi_lang_df['ROI']==roi_lang_df['ROI'].max()]
# Out:
#    original_language           ROI
# 18                ko  11277.949295

# %%
#lqng with highest avg ROI
max_ROI_lan=roi_lang_df[roi_lang_df['ROI']==roi_lang_df['ROI'].max()]['original_language']
max_ROI_lan
# Out:
# 18    ko
# Name: original_language, dtype: object

# %%
print('lang with highest avg ROI is :',max_ROI_lan.values)
# Out:
# lang with highest avg ROI is : ['ko']

# %% [markdown]
# Find out the unique genres of movies in this dataset.

# %%
genres_list=imdb_df_new['genres']
genres_list
# Out:
# 0                          [{'id': 35, 'name': 'Comedy'}]
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                           [{'id': 18, 'name': 'Drama'}]
# 3       [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#                               ...
# 2995    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997    [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# Name: genres, Length: 3000, dtype: object

# %%
diff_genres=[]
for t in genres_list:
  diff_genres.append(t['name'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-0e2a5441bfe5> in <module>()
#       1 diff_genres=[]
#       2 for t in genres_list:
# ----> 3   diff_genres.append(t['name'])
#
# TypeError: string indices must be integers

# %%
eval(no_na_genres_df['genres'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-39387d9e7481> in <module>()
# ----> 1 eval(no_na_genres_df['genres'])
#
# TypeError: eval() arg 1 must be a string, bytes or code object

# %%
no_na_genres_df=imdb_df_new[imdb_df_new['genres'].notna()]

# %%
no_na_genres_df['genres_list']=no_na_genres_df.apply(lambda row: eval(row['genres']),axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
no_na_genres_df.isna().sum()
# Out:
# budget                0
# genres                0
# imdb_id               0
# original_language     0
# original_title        0
# cast                 13
# crew                 15
# revenue               0
# Profit                0
# ROI                   0
# dtype: int64

# %%
no_na_genres_df['genres'].head()
# Out:
# 0                       [{'id': 35, 'name': 'Comedy'}]
# 1    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                        [{'id': 18, 'name': 'Drama'}]
# 3    [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# Name: genres, dtype: object

# %%
no_na_genres_df.loc[0,'genres']
# Out:
# [{'id': 35, 'name': 'Comedy'}]

# %%
no_na_genres_df.shape
# Out:
# (2993, 10)

# %%
no_na_genres_df['genres'].apply(str_converter)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-3df61016174c> in <module>()
# ----> 1 no_na_genres_df['genres'].apply(str_converter)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# ...

# %%
no_na_genres_df.iloc[0]['genres']
# Out:
# [{'id': 35, 'name': 'Comedy'}]

# %%
#iterrow is used when every row contains something we want so we need to iter over every row
#it returns a tuple with first element as index and second as row

# %%
for index, row in no_na_genres_df.iloc[0:5].iterrows():
  print(index)
  print(row)
# Out:
# 0
# budget                                                        14000000
# genres                                  [{'id': 35, 'name': 'Comedy'}]
# imdb_id                                                      tt2637294
# original_language                                                   en
# original_title                                  Hot Tub Time Machine 2
# cast                 [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# crew                 [{'credit_id': '59ac067c92514107af02c8c8', 'de...
# revenue                                                       12314651
# Profit                                                        -1685349
# ROI                                                         -12.038207
# Name: 0, dtype: object
# 1
# budget                                                        40000000
# genres               [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# imdb_id                                                      tt0368933
# ...

# %%
genres1_list=[]
for index,row in no_na_genres_df.iterrows():
  genre2_list=row['genres']
  for elem in genre_list:
    genres1_list.append(elem['name'])

# %%
genres1_list
# we have repetitions, lets use set() to get unique values
# Out:
# ['Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Action',
# ...

# %%
set(genres1_list)
# Out:
# {'Action', 'Mystery', 'Thriller'}

# %%
genre2_list
# Out:
# [{'id': 53, 'name': 'Thriller'},
#  {'id': 28, 'name': 'Action'},
#  {'id': 9648, 'name': 'Mystery'}]

# %% [markdown]
# Make a table of all the producers and directors of each movie. Find the top 3 producers who have produced movies with the highest average RoI?

# %%
imdb_df2=imdb_df.copy()

# %%
imdb_no_null_crew=imdb_df_new[imdb_df_new['crew'].notna()]
imdb_df2_no_null_crew=imdb_df2[imdb_df2['crew'].notna()]

# %%
imdb_no_null_crew.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4  16450000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
imdb_df2_no_null_crew.head()
# Out:
#      budget                                             genres    imdb_id  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]  tt2637294
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  tt0368933
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]  tt2582802
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...  tt1821480
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# ...

# %%
len(imdb_df2_no_null_crew)
# Out:
# 2984

# %%
len(imdb_no_null_crew)
# Out:
# 2984

# %%
imdb_no_null_crew.iloc[0]['crew']
# Out:
# '[{\'credit_id\': \'59ac067c92514107af02c8c8\', \'department\': \'Directing\', \'gender\': 0, \'id\': 1449071, \'job\': \'First Assistant Director\', \'name\': \'Kelly Cantley\', \'profile_path\': None}, {\'credit_id\': \'52fe4ee7c3a36847f82afad7\', \'department\': \'Directing\', \'gender\': 2, \'id\': 3227, \'job\': \'Director\', \'name\': \'Steve Pink\', \'profile_path\': \'/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg\'}, {\'credit_id\': \'5524ed25c3a3687ded000d88\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Writer\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed2d925141720c001128\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Characters\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed3d92514166c1004a5d\', \'department\': \'Production\', \'gender\': 2, \'id\': 57822, \'job\': \'Producer\', \'name\': \'Andrew Panay\',
# ...

# %%
imdb_df2_no_null_crew.iloc[0]['crew']
# Out:
# '[{\'credit_id\': \'59ac067c92514107af02c8c8\', \'department\': \'Directing\', \'gender\': 0, \'id\': 1449071, \'job\': \'First Assistant Director\', \'name\': \'Kelly Cantley\', \'profile_path\': None}, {\'credit_id\': \'52fe4ee7c3a36847f82afad7\', \'department\': \'Directing\', \'gender\': 2, \'id\': 3227, \'job\': \'Director\', \'name\': \'Steve Pink\', \'profile_path\': \'/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg\'}, {\'credit_id\': \'5524ed25c3a3687ded000d88\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Writer\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed2d925141720c001128\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Characters\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed3d92514166c1004a5d\', \'department\': \'Production\', \'gender\': 2, \'id\': 57822, \'job\': \'Producer\', \'name\': \'Andrew Panay\',
# ...

# %%
def get_producers_and_directors(crew_list):
  try:
    producer_list=[]
    director_list=[]

    for elem in crew_list:
      if elem['job']=='Producer':
        producer_list.append(elem['name'])
      if elem['job']=='Director':
        director_list.append(elem['name'])
  except:
    return [],[]

# %%
get_producers_and_directors(crew_list)

# %%
crew_list
# Out:
# [{'credit_id': '52fe4cc8c3a36847f823e681',
#   'department': 'Production',
#   'gender': 2,
#   'id': 12835,
#   'job': 'Producer',
#   'name': 'Vin Diesel',
#   'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e687',
#   'department': 'Production',
#   'gender': 2,
#   'id': 11874,
#   'job': 'Producer',
#   'name': 'Neal H. Moritz',
#   'profile_path': '/cNcsEYmoS4niCz3UkVAA09dUIob.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e68d',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 58191,
#   'job': 'Writer',
#   'name': 'Chris Morgan',
#   'profile_path': '/dUGxIwFBLrSFLImxjeda1krndMO.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e693',
#   'department': 'Writing',
#   'gender': 0,
#   'id': 8162,
#   'job': 'Characters',
#   'name': 'Gary Scott Thompson',
#   'profile_path': '/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e699',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 2127,
# ...

# %%
get_producers_and_directors(imdb_no_null_crew.loc[0,'crew'])
# Out:
# ([], [])

# %%
get_producers_and_directors(imdb_df2_no_null_crew.loc[0,'crew'])
# Out:
# ([], [])

# %%
  #extra knowledge 1
  _df = pd.DataFrame([['ant', 'bee', 'cat'], ['dog', None, 'fly']])
  _df
# Out:
#      0     1    2
# 0  ant   bee  cat
# 1  dog  None  fly

# %%
#it is referring directly to columns ....this is pandas df, df[] refers to column only
_df[0]
# Out:
# 0    ant
# 1    dog
# Name: 0, dtype: object

# %%
_df[1]
# Out:
# 0     bee
# 1    None
# Name: 1, dtype: object

# %%
_df[2]
# Out:
# 0    cat
# 1    fly
# Name: 2, dtype: object

# %%
#extra knowledge 2
